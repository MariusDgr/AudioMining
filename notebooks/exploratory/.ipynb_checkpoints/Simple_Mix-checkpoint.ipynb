# %%
import os 

# matplotlib for displaying the output
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# sns.set()
sns.set(style="ticks", context="talk")

import numpy as np
import scipy
from scipy.io import wavfile
import wave
import struct

# and IPython.display for audio output
import IPython.display

# Librosa for audio
import librosa
# And the display module for visualization
import librosa.display

# %%
two_up =  os.path.abspath(os.path.join('.' ,"../.."))
print("Project root path is: ", two_up)

dataDirName = "data"
rawDataDirName = "test_data"
className = "simple_sine"
data_path = os.path.join(two_up, dataDirName, rawDataDirName, className)
# Out:
# Project root path is:  D:\Programming\AudioMining

# %%
# frequency is the number of times a wave repeats a second
frequency = 1000
num_samples = 48000
 
# The sampling rate of the analog to digital convert
sampling_rate = 48000
amplitude = 12000

# generate sine wave
s_wave = [np.sin(2 * np.pi * frequency * x/sampling_rate) for x in range(num_samples)]

# %%
# Generate second signal 
frequency = 2000
num_samples2 = 24000
 
# The sampling rate of the analog to digital convert
sampling_rate = 48000

# generate sine wave
s_wave2 = [np.sin(2 * np.pi * frequency * x/sampling_rate)/2 for x in range(num_samples2)]

# %%
# pad with 0 
signal2 = [0 for x in range(num_samples2)] + s_wave2

# overlap signals
mixed_signal = np.add(np.asarray(s_wave), np.asarray(signal2))

# %%
# Get fast fourier transform
data = np.array(mixed_signal)

N = len(data)
yf = scipy.fft(data[data.shape[0]//2:])
yf = 2.0/N * np.abs(yf[:N//2])
xf = np.linspace(0.0, sampling_rate/2.0, N/2)
# Out:
# c:\users\marius\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   import sys

# %%
# Plot part of signal and fft
plt.subplot(2,1,1)
plt.plot(data[data.shape[0]//2 - 50 : data.shape[0]//2 + 50])
plt.title("Original audio wave")
plt.subplot(2,1,2)

plt.plot(xf, yf)
plt.title("Frequencies found")
plt.xlim(0,3000)
plt.tight_layout(pad=1.0)
plt.show()

# %%
S = librosa.feature.melspectrogram(mixed_signal, sr=sampling_rate, n_mels=128, fmax=9000)

# Convert to log scale (dB). We'll use the peak power (max) as reference.
log_S = librosa.power_to_db(S, ref=np.max)

# Make a new figure
plt.figure(figsize=(12,4))

# Display the spectrogram on a mel scale
# sample rate and hop length parameters are used to render the time axis
librosa.display.specshow(log_S, sr=sampling_rate, x_axis='time', y_axis='mel', fmax=9000)

# Put a descriptive title on the plot
plt.title('mel power spectrogram')

# draw a color bar
plt.colorbar(format='%+02.0f dB')

# Make the figure layout compact
plt.tight_layout()

# %%
IPython.display.Audio(mixed_signal, rate=sampling_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
n_fft = 2048
stft = np.abs(librosa.stft(data, n_fft=n_fft))

# log_Stft = librosa.power_to_db(stft, ref=np.max)

plt.figure(figsize=(12,4))

librosa.display.specshow(stft, x_axis='time', y_axis='log', sr=sampling_rate)

# draw a color bar
plt.colorbar()
plt.tight_layout()

# %%
D = librosa.amplitude_to_db(np.abs(librosa.stft(data)), ref=np.max)
plt.figure(figsize=(12,4))
librosa.display.specshow(D, y_axis='log', sr=sampling_rate)
plt.colorbar(format='%+2.0f dB')
plt.title('Linear-frequency power spectrogram');

# %%
plt.figure(figsize=(12,4))
librosa.display.specshow(D, y_axis='log', sr=sampling_rate)
plt.colorbar(format='%+2.0f dB')
plt.title('Log-frequency power spectrogram')
# Out:
# Text(0.5,1,'Log-frequency power spectrogram')

# %%
CQT = librosa.amplitude_to_db(librosa.cqt(data, sr=sampling_rate), ref=np.max)
plt.figure(figsize=(12,4))
librosa.display.specshow(CQT, y_axis='cqt_hz')
plt.colorbar(format='%+2.0f dB')
plt.title('Constant-Q power spectrogram (note)')
# Out:
# c:\users\marius\appdata\local\programs\python\python36\lib\site-packages\librosa\core\spectrum.py:1700: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   warnings.warn('amplitude_to_db was called on complex input so phase '
# Text(0.5,1,'Constant-Q power spectrogram (note)')

# %%
fourier = np.fft.fft(mixed_signal)
n = mixed_signal.size
timestep = 1.0/sampling_rate
freq = np.fft.fftfreq(n, d=timestep)
plt.plot(freq[:n//2], 2/sampling_rate * np.abs(fourier[:n//2]))
plt.xlim(0, 3000)
plt.show()

# %%
# if dealing with time
def FFT(t, y):
    n = len(t)
    Δ = (max(t) - min(t)) / (n-1)
    k = int(n/2)
    f = np.arange(k) / (n*Δ)
    Y = abs(np.fft.fft(y))[:k]
    return (f, Y)

# if already have the sampling rate
def FFT_sr(sr, y):
    n = len(y)
    k = int(n/2)
    f = np.arange(k) / (n/sr)
    Y = abs(np.fft.fft(y))[:k]
    return (f, Y)

# %%
(f, Y) = FFT_sr(sampling_rate, mixed_signal)

# Plot part of signal and fft
plt.subplot(2,1,1)
plt.plot(mixed_signal[:100])
plt.title("Original audio wave")
plt.subplot(2,1,2)
plt.plot(f, Y)
plt.title("Frequencies found")
plt.xlim(0,3000)
plt.tight_layout(pad=1.0)
plt.show()

# %%
# test saving 
nframes=num_samples 
comptype="NONE"
compname="not compressed" 
nchannels=1
sampwidth=2
filename = "samplingrate_save.wav"

wav_file = wave.open(os.path.join(data_path, filename), 'w')
wav_file.setparams((nchannels, sampwidth, int(sampling_rate), nframes, comptype, compname))

for s in mixed_signal:
   wav_file.writeframes(struct.pack('h', int(s*amplitude)))

# %%
s_data, s_sr =  librosa.load(os.path.join(data_path, filename), sr=sampling_rate)
