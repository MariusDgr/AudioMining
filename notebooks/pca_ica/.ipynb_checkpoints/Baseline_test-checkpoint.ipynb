# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os 
import sys

projRootPath =  os.path.abspath(os.path.join('.' ,"../.."))
print("Project root path is: ", projRootPath)
sys.path.append(projRootPath)

from src.utils.path_manipulation import contains_filetype
from src.utils.viz_functions import make_mel_spectrogram
from src.utils.sound_functions import mix_samples, read_mp3, write_mp3, pad_length_to_max

# modules for visuals
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# modules for data processing
import numpy as np
from scipy import signal
from scipy.io import wavfile
from statistics import median
import wave
import struct
import csv
import random
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error 

# modules for data mining
from sklearn.decomposition import pca, FastICA

# and IPython.display for audio output
from tqdm.notebook import tqdm 
import IPython.display

# Librosa for audio
import librosa
# And the display module for visualization
import librosa.display

from pydub import AudioSegment
# Out:
# Project root path is:  D:\Programming\AudioMining

# %%
fs = 1000
f1 = 1
f2 = 2

x = np.arange(fs)

wave1 = np.sin(2*np.pi*f1 * (x/fs))
wave2 = np.sin(2*np.pi*f2 * (x/fs))

# %%
plt.plot(x, wave1, x, wave2)
# Out:
# [<matplotlib.lines.Line2D at 0x1eabb307b38>,
#  <matplotlib.lines.Line2D at 0x1eabb307dd8>]

# %%
def generate_mixtures(s1, s2, mixing_matrix):
    S = np.c_[s1, s2]
    S = MinMaxScaler([-1, 1]).fit_transform(S)
    A = np.array(mixing_matrix)
    X = np.dot(S, A.T)
    return S, X

def pair_randomizer(n):
    pairs = []
    for i in range(n):
        pair = np.random.random(2)*3
        pairs.append(pair)
    return pairs

def sample_evaluation(v1, v2, s1, s2, only_min):
    """
    s1, s2: known samples
    v1, v2: samples to be identified
    only_min : if True return only the smallest value
    """
    scaler = MinMaxScaler([-1, 1])
    v1 = scaler.fit_transform(v1.reshape(-1, 1))
    scaler = MinMaxScaler([-1, 1])
    v2 = scaler.fit_transform(v2.reshape(-1, 1))
    
    mse_v1_min_s1 = min(mean_squared_error(s1, v1), mean_squared_error(s1, -1*v1))
    mse_v1_min_s2 = min(mean_squared_error(s2, v1), mean_squared_error(s2, -1*v1))
    
    mse_v2_min_s1 = min(mean_squared_error(s1, v2), mean_squared_error(s1, -1*v2))
    mse_v2_min_s2 = min(mean_squared_error(s2, v2), mean_squared_error(s2, -1*v2))
    
    if only_min:
        val = min(min(mse_v1_min_s1, mse_v1_min_s2), min(mse_v2_min_s1, mse_v2_min_s2))
    else:
        val = min(mse_v1_min_s1, mse_v1_min_s2) + min(mse_v2_min_s1, mse_v2_min_s2)
    return val

# %%
# Do ICA
sub_mtx = pair_randomizer(10)

S_orig, mixed_signals = generate_mixtures(wave1, wave2, sub_mtx)
new_mixtures = np.asarray(mixed_signals)

ica_st = FastICA(n_components=2)
S_recov = ica_st.fit_transform(new_mixtures) # Reconstruct signals
A_recov = ica_st.mixing_  # Get estimated mixing matrix

# %%
mixed_signals.shape
# Out:
# (1000, 10)

# %%
plt.plot(x, wave1, x, S_orig[:, 0])
# Out:
# [<matplotlib.lines.Line2D at 0x1eabd3b5978>,
#  <matplotlib.lines.Line2D at 0x1eabd3b5b70>]

# %%
# plot recovered signals
plt.plot(x, S_recov[:, 0], x, S_recov[:, 1])
# Out:
# [<matplotlib.lines.Line2D at 0x1eabd426860>,
#  <matplotlib.lines.Line2D at 0x1eabd426a58>]

# %%
# plot original signals
plt.plot(x, S_orig[:, 0], x, S_orig[:, 1])
# Out:
# [<matplotlib.lines.Line2D at 0x1eabd48d0b8>,
#  <matplotlib.lines.Line2D at 0x1eabd48d2b0>]

# %%
sample_evaluation(S_recov[:, 0], S_recov[:, 1], S_orig[:, 0], S_orig[:, 1], False)
# Out:
# 2.3662176125387865e-06

# %%
# rescale recovered signals
recov_wave1 = MinMaxScaler([-1, 1]).fit_transform(S_recov[:, 0].reshape(-1, 1))
recov_wave2 = MinMaxScaler([-1, 1]).fit_transform(S_recov[:, 1].reshape(-1, 1))

# %%
plt.plot(x, -1*recov_wave2, x, S_orig[:, 1])
# Out:
# [<matplotlib.lines.Line2D at 0x1eabd4f3dd8>,
#  <matplotlib.lines.Line2D at 0x1eabd4f3fd0>]

# %%
plt.plot(x, -1*recov_wave1, x, S_orig[:, 0])
# Out:
# [<matplotlib.lines.Line2D at 0x1eabe8eac18>,
#  <matplotlib.lines.Line2D at 0x1eabe8eae10>]

# %%
# validate decomposition with pinv

S_recov_validate = np.dot(new_mixtures, np.linalg.pinv(A_recov.T))
recov_validation_wave1 = MinMaxScaler([-1, 1]).fit_transform(S_recov_validate[:, 0].reshape(-1, 1))
recov_validation_wave2 = MinMaxScaler([-1, 1]).fit_transform(S_recov_validate[:, 1].reshape(-1, 1))

# %%
plt.plot(x, recov_validation_wave1, x, recov_validation_wave2)
# Out:
# [<matplotlib.lines.Line2D at 0x1eabed04588>,
#  <matplotlib.lines.Line2D at 0x1eabed04780>]

# %% [markdown]
# ### Try to decompose a mixed signal from the training set

# %%
mixed_signals.shape
# Out:
# (1000, 2)

# %% [markdown]
# ### plot mixture
# plt.plot(x, mixed_signals[:, 2])

# %%
plt.plot(x, mixed_signals[:, 4])

# %%
for i in range(5):
    plt.plot(x, mixed_signals[:, i])

# %%
 # plot mixture 
mixts_single = mixed_signals[:, 1]
mixts_repeated = np.tile(np.array(mixts_single), (A_recov.shape[0], 1))
mixts_repeated = np.asarray(mixts_repeated.T)

S_recov_single_obs = np.dot(mixts_repeated, np.linalg.pinv(A_recov.T))
recov_single_wave1 = MinMaxScaler([-1, 1]).fit_transform(S_recov_single_obs[:, 0].reshape(-1, 1))
recov_single_wave2 = MinMaxScaler([-1, 1]).fit_transform(S_recov_single_obs[:, 1].reshape(-1, 1))

# %%
plt.plot(x, S_recov_single_obs[:, 0], x, S_recov_single_obs[:, 1])
# Out:
# [<matplotlib.lines.Line2D at 0x1eabec9dd30>,
#  <matplotlib.lines.Line2D at 0x1eabec9df28>]

# %%
plt.plot(x, recov_single_wave1, x, S_orig[:, 1])
# Out:
# [<matplotlib.lines.Line2D at 0x1eabe6dd940>,
#  <matplotlib.lines.Line2D at 0x1eabe6ddb38>]

# %%
# plot mixture 
plt.plot(x, mixed_signals[:, 2])

# %%
 # plot mixture 
mixts_single = mixed_signals[:, 2]
mixts_repeated = np.tile(np.array(mixts_single), (A_recov.shape[0], 1))
mixts_repeated = np.asarray(mixts_repeated.T)

S_recov_single_obs = np.dot(mixts_repeated, np.linalg.pinv(A_recov.T))
recov_single_wave1 = MinMaxScaler([-1, 1]).fit_transform(S_recov_single_obs[:, 0].reshape(-1, 1))
recov_single_wave2 = MinMaxScaler([-1, 1]).fit_transform(S_recov_single_obs[:, 1].reshape(-1, 1))

# %%
plt.plot(x, recov_single_wave1, x, recov_single_wave2)
# Out:
# [<matplotlib.lines.Line2D at 0x1eabe7b0278>,
#  <matplotlib.lines.Line2D at 0x1eabe7b0470>]

# %%
mixts_repeated.shape
# Out:
# (1000, 10)

# %% [markdown]
# ### Batch test

# %%
s1_st = wave1 
s2_st = wave2 

# scale the initial samples
scaler = MinMaxScaler([-1, 1])
s1_st = scaler.fit_transform(s1_st.reshape(-1, 1))
scaler = MinMaxScaler([-1, 1])
s2_st = scaler.fit_transform(s2_st.reshape(-1, 1))

batch_size = 10

mse_list = []
for i in tqdm(range(2, 15)):
    
    mse_batch = []
    for j in range(batch_size):
    
        sub_mtx = pair_randomizer(i)

        S_v_orig_st, mixts_v_st = generate_mixtures(s1_st, s2_st, sub_mtx)
        new_mixtures_st = np.asarray(mixts_v_st)

        ica_st = FastICA(n_components=2)
        S_recov_v_st = ica_st.fit_transform(new_mixtures_st) # Reconstruct signals
        A_recov_v_other_st = ica_st.mixing_  # Get estimated mixing matrix
        
        # evaluate decomposition
        mse_batch.append(sample_evaluation(S_recov_v_st[:, 0], S_recov_v_st[:, 1], s1_st, s2_st, False)) 
        
    
    mse_list.append(median(mse_batch))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=13.0), HTML(value='')))

# %%
plt.plot(mse_list)

# %%
sub_mtx = pair_randomizer(2)

S_orig, mixed_signals = generate_mixtures(wave1, wave2, sub_mtx)
new_mixtures = np.asarray(mixed_signals)

ica_st = FastICA(n_components=2)
S_recov = ica_st.fit_transform(new_mixtures) # Reconstruct signals
A_recov = ica_st.mixing_  # Get estimated mixing matrix

# %%
# plot recovered signals
plt.plot(x, S_recov[:, 0], x, S_recov[:, 1])
# Out:
# [<matplotlib.lines.Line2D at 0x1eabe891b70>,
#  <matplotlib.lines.Line2D at 0x1eabe891d68>]

# %%
# plot mixture 
mixts_single1 = mixed_signals[:, 1]
mixts_repeated1 = np.tile(np.array(mixts_single1), (2, 1))

mixts_single2 = mixed_signals[:, 2]
mixts_repeated2 = np.tile(np.array(mixts_single2), (2, 1))

mixts_single3 = mixed_signals[:, 3]
mixts_repeated3 = np.tile(np.array(mixts_single3), (2, 1))

mixts_single4 = mixed_signals[:, 4]
mixts_repeated4 = np.tile(np.array(mixts_single4), (2, 1))

mixts_single5 = mixed_signals[:, 5]
mixts_repeated5 = np.tile(np.array(mixts_single5), (2, 1))

mixts_5 = np.concatenate((mixts_repeated1, mixts_repeated2, mixts_repeated3, mixts_repeated4 , mixts_repeated5), axis=0)
mixts_repeated = np.asarray(mixts_5.T)

# %%
mixts_single = mixed_signals[:, 9]
mixts_repeated = np.tile(np.array(mixts_single), (1, 1))

    
for i in range(8, -1, -1):
    mixts_single = mixed_signals[:, i]
    mixts_repeated_n = np.tile(np.array(mixts_single), (1, 1))
    mixts_repeated = np.concatenate((mixts_repeated, mixts_repeated_n), axis=0)
    
mixts_repeated = np.asarray(mixts_repeated.T)

# %%
mixts_single = mixed_signals[:, 0]
mixts_repeated = np.tile(np.array(mixts_single), (3, 1))

    
for i in range(3, 10):
    mixts_single = mixed_signals[:, i]
    mixts_repeated_n = np.tile(np.array(mixts_single), (1, 1))
    mixts_repeated = np.concatenate((mixts_repeated, mixts_repeated_n), axis=0)
    
mixts_repeated = np.asarray(mixts_repeated.T)

# %%
mixts_repeated.shape
# Out:
# (1000, 10)

# %%
np.linalg.pinv(A_recov.T).shape
# Out:
# (10, 2)

# %%
S_recov_single_obs = np.dot(mixts_repeated, np.linalg.pinv(A_recov.T))
recov_single_wave1 = MinMaxScaler([-1, 1]).fit_transform(S_recov_single_obs[:, 0].reshape(-1, 1))
recov_single_wave2 = MinMaxScaler([-1, 1]).fit_transform(S_recov_single_obs[:, 1].reshape(-1, 1))

# %%
plt.plot(x, recov_single_wave1, x, recov_single_wave2)
# Out:
# [<matplotlib.lines.Line2D at 0x1eac03d2390>,
#  <matplotlib.lines.Line2D at 0x1eac03d2588>]

# %%
plt.plot(x, mixed_signals[:, 2])

# %%
A_recov.shape
# Out:
# (10, 2)

# %%
test_obs =  mixed_signals[:, 2]
mixts_repeated_n = np.tile(np.array(test_obs), (1, 1))
mixts_repeated = np.asarray(mixts_repeated_n.T)
 
model_pair = np.linalg.pinv(A_recov.T)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-160-c494107f6ff8> in <module>()
#       4
#       5
# ----> 6 model_pair = np.linalg.pinv(A_recov[2, :])
#
# c:\users\marius\appdata\local\programs\python\python36\lib\site-packages\numpy\linalg\linalg.py in pinv(a, rcond)
#    1936         return wrap(res)
#    1937     a = a.conjugate()
# -> 1938     u, s, vt = svd(a, full_matrices=False)
#    1939
#    1940     # discard small singular values
#
# c:\users\marius\appdata\local\programs\python\python36\lib\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv)
#    1591     """
#    1592     a, wrap = _makearray(a)
# -> 1593     _assertRankAtLeast2(a)
#    1594     t, result_t = _commonType(a)
#    1595
#
# c:\users\marius\appdata\local\programs\python\python36\lib\site-packages\numpy\linalg\linalg.py in _assertRankAtLeast2(*arrays)
#     205         if a.ndim < 2:
#     206             raise LinAlgError('%d-dimensional array given. Array must be '
# --> 207                     'at least two-dimensional' % a.ndim)
#     208
#     209 def _assertNdSquareness(*arrays):
#
# LinAlgError: 1-dimensional array given. Array must be at least two-dimensional

# %%
mixts_repeated.shape
# Out:
# (1000, 1)

# %%
model_pair = np.tile(np.array(model_pair), (1, 1))

# %%
model_pair.shape
# Out:
# (1, 2)

# %%
S_recov_single_obs = np.dot(mixts_repeated, model_pair)
recov_single_wave1 = MinMaxScaler([-1, 1]).fit_transform(S_recov_single_obs[:, 0].reshape(-1, 1))
recov_single_wave2 = MinMaxScaler([-1, 1]).fit_transform(S_recov_single_obs[:, 1].reshape(-1, 1))

# %%
plt.plot(x, recov_single_wave1, x, recov_single_wave2)
# Out:
# [<matplotlib.lines.Line2D at 0x1eac056d710>,
#  <matplotlib.lines.Line2D at 0x1eac056d898>]

# %%
my_pinv = np.linalg.pinv(A_recov.T)
model_p = my_pinv[2, :]
model_p = np.tile(np.array(model_p), (1, 1))

# %%
mixts_repeated.shape
# Out:
# (1000, 1)

# %%
S_recov_single_obs = np.dot(mixts_repeated, model_p)
recov_single_wave1 = MinMaxScaler([-1, 1]).fit_transform(S_recov_single_obs[:, 0].reshape(-1, 1))
recov_single_wave2 = MinMaxScaler([-1, 1]).fit_transform(S_recov_single_obs[:, 1].reshape(-1, 1))

# %%
plt.plot(x, recov_single_wave1, x, recov_single_wave2)
# Out:
# [<matplotlib.lines.Line2D at 0x1eac05c3cf8>,
#  <matplotlib.lines.Line2D at 0x1eac05c3ef0>]

# %%
## 2 obs 2 pair
test_obs = mixed_signals[:, 2]
mixts_repeated_n = np.tile(np.array(test_obs), (1, 1))
mixts_repeated = np.asarray(mixts_repeated_n.T)

# %%
np.linalg.pinv(A_recov.T)

# %%
for i in range(10):
    my_pinv = np.linalg.pinv(A_recov.T)
    model_p = my_pinv[i, :]
    model_p = np.tile(np.array(model_p), (1, 1))
    S_recov_single_obs = np.dot(mixts_repeated, model_p)
    recov_single_wave1 = MinMaxScaler([-1, 1]).fit_transform(S_recov_single_obs[:, 0].reshape(-1, 1))
    recov_single_wave2 = MinMaxScaler([-1, 1]).fit_transform(S_recov_single_obs[:, 1].reshape(-1, 1))
    plt.figure()
    plt.plot(x, recov_single_wave1, x, recov_single_wave2)
